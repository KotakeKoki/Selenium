# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import sys

browser= webdriver.Chrome()
df = pd.DataFrame()
gene = pd.DataFrame()

with open('Objective_genes.txt') as f:
    for line in f.readlines():
        try:
            url= "https://www.ncbi.nlm.nih.gov/"
            browser.get(url)
            search_win = browser.find_element(By.ID,"term")
            search_win.send_keys(line)
            
            # searchボタンを押さなければいけない時と押さなくてもいい時がある(謎)これを解決
            try: 
                search_button = browser.find_element(By.ID,"search")
                search_button.click()
            except:
                pass
            
            #遺伝子名をAlso known asで検索してしまったときにidが変わる問題を解決
            try: 
                gene = browser.find_element(By.ID,"feat_gene_title")
                gene.click()
            except:
                gene = browser.find_element(By.ID,"gene_title")
                gene.click()
            
            res = requests.get(url)
            res
            soup = BeautifulSoup(res.text,"html.parser")
            
            gene ={}
            name = browser.find_element(By.CLASS_NAME,"title")
            gene_url = browser.current_url

            gene["name"] = name.text
            gene["url"] = gene_url
            
            res = requests.get(gene_url)
            
            soup = BeautifulSoup(res.text,"html.parser")

            categoryItems = soup.find("dl",attrs={"id":"summaryDl"})
            categoryItems = categoryItems.find_all("dd")
            gene["gene_type"] = categoryItems[4].text
            gene["also_known_as"] = categoryItems[8].text
            gene["summary"] = categoryItems[9].text 
            
            
            # -
            Location = soup.find("div",attrs={"class":"gt_cont_contents"})
            gene["Location"] = Location.find_all("span")[1].text
            #dfに個々の遺伝子のデータを順に追加していく。
            if "df" in globals():
                gene_df = pd.DataFrame(gene,index = [0])
                df = pd.concat([gene_df,df],axis=0)
            else:
                df= pd.DataFrame(gene,index = [0])
        except Exception as e:
            gene = {}
            gene["name"] = line
            gene["url"] = e
            gene_df = pd.DataFrame(gene,index = [0])
            df = pd.concat([gene_df,df],axis=0)
        
df.to_csv("gene.csv",index = False)
browser.quit()

# %%
gene_df
df
#joined
# Out:
#                                                 name  \
# 0  IRS1 insulin receptor substrate 1 [ Homo sapie...
# 0           GCK glucokinase [ Homo sapiens (human) ]
# 0  GCKR glucokinase regulator [ Homo sapiens (hum...
# 0  MTNR1B melatonin receptor 1B [ Homo sapiens (h...
# 0  G6PC2 glucose-6-phosphatase catalytic subunit ...
# 0   NOTCH2 notch receptor 2 [ Homo sapiens (human) ]
# 0  ADAMTS9 ADAM metallopeptidase with thrombospon...
# 0                                            THADA\n
# 0      TSPAN8 tetraspanin 8 [ Homo sapiens (human) ]
# 0  CDC123 cell division cycle 123 [ Homo sapiens ...
# 0                                            JAZF1\n
# 0  WFS1 wolframin ER transmembrane glycoprotein [...
# 0                                             TCF2\n
# 0  CDKAL1 CDK5 regulatory subunit associated prot...
# 0  IGF2BP2 insulin like growth factor 2 mRNA bind...
# 0  CDKN2A cyclin dependent kinase inhibitor 2A [ ...
# 0  HHEX hematopoietically expressed homeobox [ Ho...
# 0  SLC30A8 solute carrier family 30 member 8 [ Ho...
# 0  FTO FTO alpha-ketoglutarate dependent dioxygen...
# 0  TCF7L2 transcription factor 7 like 2 [ Homo sa...
# 0  KCNJ11 potassium inwardly rectifying channel s...
# 0  PPARG peroxisome proliferator activated recept...
#
#                                                  url       gene_type  \
# 0             https://www.ncbi.nlm.nih.gov/gene/3667  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/2645  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/2646  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/4544  protein coding
# 0            https://www.ncbi.nlm.nih.gov/gene/57818  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/4853  protein coding
# 0            https://www.ncbi.nlm.nih.gov/gene/56999  protein coding
# 0  Message: no such element: Unable to locate ele...             NaN
# 0             https://www.ncbi.nlm.nih.gov/gene/7103  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/8872  protein coding
# 0  Message: no such element: Unable to locate ele...             NaN
# 0             https://www.ncbi.nlm.nih.gov/gene/7466  protein coding
# 0  Message: no such element: Unable to locate ele...             NaN
# 0            https://www.ncbi.nlm.nih.gov/gene/54901  protein coding
# 0            https://www.ncbi.nlm.nih.gov/gene/10644  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/1029  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/3087  protein coding
# 0           https://www.ncbi.nlm.nih.gov/gene/169026  protein coding
# 0            https://www.ncbi.nlm.nih.gov/gene/79068  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/6934  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/3767  protein coding
# 0             https://www.ncbi.nlm.nih.gov/gene/5468  protein coding
#
#                                        also_known_as  \
# 0                                             HIRS-1
# 0  GK; GLK; HK4; HHF3; HKIV; HXKP; LGLK; MODY2; P...
# 0                                       GKRP; FGQTL5
# 0                              MT2; FGQTL2; MEL-1B-R
# 0                                               IGRP
# 0                                   hN2; AGS2; HJCYS
# 0  This gene encodes a member of the ADAMTS (a di...
# 0                                                NaN
# 0                                     CO-029; TM4SF3
# 0                                      D123; C10orf7
# 0                                                NaN
# 0                           WFS; WFRS; WFSL; CTRCT41
# 0                                                NaN
# 0  The protein encoded by this gene is a member o...
# 0                                IMP2; IMP-2; VICKZ2
# 0  ARF; MLM; P14; P16; P19; CMM2; INK4; MTS1; TP1...
# 0                   HEX; PRH; HMPH; PRHX; HOX11L-PEN
# 0                                        ZNT8; ZnT-8
# 0                               GDFD; ALKBH9; BMIQ14
# 0                                        TCF4; TCF-4
# 0  BIR; HHF2; PHHI; IKATP; PNDM2; TNDM3; KIR6.2; ...
# 0  GLM1; CIMT1; NR1C3; PPARG1; PPARG2; PPARG5; PP...
#
#                                              summary       Location
# 0  This gene encodes a protein which is phosphory...         2q36.3
# 0  This gene encodes a member of the hexokinase f...           7p13
# 0  This gene encodes a protein belonging to the G...         2p23.3
# 0  This gene encodes one of two high affinity for...        11q14.3
# 0  This gene encodes an enzyme belonging to the g...         2q31.1
# 0  This gene encodes a member of the Notch family...           1p12
# 0  Broad expression in placenta (RPKM 16.1), endo...         3p14.1
# 0                                                NaN            NaN
# 0  The protein encoded by this gene is a member o...        12q21.1
# 0  Predicted to be involved in eukaryotic transla...      10p14-p13
# 0                                                NaN            NaN
# 0  This gene encodes a transmembrane protein, whi...         4p16.1
# 0                                                NaN            NaN
# 0  Ubiquitous expression in thyroid (RPKM 1.8), e...         6p22.3
# 0  This gene encodes a protein that binds the 5' ...         3q27.2
# 0  This gene generates several transcript variant...         9p21.3
# 0  This gene encodes a member of the homeobox fam...       10q23.33
# 0  The protein encoded by this gene is a zinc eff...        8q24.11
# 0  This gene is a nuclear protein of the AlkB rel...        16q12.2
# 0  This gene encodes a high mobility group (HMG) ...  10q25.2-q25.3
# 0  Potassium channels are present in most mammali...        11p15.1
# 0  This gene encodes a member of the peroxisome p...         3p25.2
