# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import sys

# %%
#mouseのオルソログの情報を持ってくる。
def mouse_Orthologs():
    ortholog = browser.find_element(By.LINK_TEXT,"mouse")
    ortholog.click()
    
#Rattusのオルソログを持ってくる。
def Rattus_Ortholog():
    ortholog = browser.find_element(By.LINK_TEXT,"all")
    ortholog.click()
    #tag = browser.find_element_by_css_selector('a[data-ga-label="Rattus norvegicus"]')
    #ここ、コード書くときに詰まった。SeleniumでHTMLの出力→CSSセレクタでの指定が便利だ。
    tag = browser.find_element(By.CSS_SELECTOR,'a[data-ga-label="Rattus norvegicus"]')
    tag.click()
    #ここで新しいタブが開いてしまう。一旦新しいタブに操作を移動させたのち、昔のタブを消す。
    #こうするとタブはかさまず動き続けてくれる。
    sleep(5)
    browser.switch_to.window(browser.window_handles[1])
    browser.switch_to.window(browser.window_handles[0])
    browser.close()
    browser.switch_to.window(browser.window_handles[0])

#同じ方法で各動物のオルソログを取ってくる関数も書けるだろう。各動物種に対応可能。

# %%
browser= webdriver.Chrome()
df = pd.DataFrame()
gene_df = pd.DataFrame()

#Objective_genes.txtファイルに改行区切りで遺伝子名を入れておく。
with open('Objective_genes.txt') as f:
    for line in f.readlines():
        try:
            url= "https://www.ncbi.nlm.nih.gov/"
            browser.get(url)
            search_win = browser.find_element(By.ID,"term")
            search_win.send_keys(line)
            
            # searchボタンを押さなければいけない時と押さなくてもいい時がある(謎)これを解決
            try: 
                search_button = browser.find_element(By.ID,"search")
                search_button.click()
            except:
                pass
            
            #遺伝子名をAlso known asに指定される名前で検索してしまったとき、リンクのidが変わる問題を解決
            try: 
                gene = browser.find_element(By.ID,"feat_gene_title")
                gene.click()
            except:
                gene = browser.find_element(By.ID,"gene_title")
                gene.click()
            
            #humanの情報でいいときはここをコメントアウトする。ラットのオルソログがないものもあるので、その分エラーも増える。
            Rattus_Ortholog()
            #逆にマウスの情報が欲しい時は＃を消す
            #mouse_Orthologs()
            
            #gene一つずつ、辞書を作ってdfに入れては辞書を初期化する手法をとる。
            gene ={}
            name = browser.find_element(By.CLASS_NAME,"title")
            gene_url = browser.current_url
            
            gene["name"] = name.text
            gene["url"] = gene_url
            
            #Beautiful Soupで読み取るためのお膳立て(res)
            res = requests.get(gene_url)
            soup = BeautifulSoup(res.text,"html.parser")
            categoryItems = soup.find("dl",attrs={"id":"summaryDl"})
            categoryItems = categoryItems.find_all("dd")
            gene["gene_type"] = categoryItems[4].text
            gene["also_known_as"] = categoryItems[8].text
            gene["summary"] = categoryItems[9].text 
            #必要な情報が増える場合、ここで調節
            
            Location = soup.find("div",attrs={"class":"gt_cont_contents"})
            gene["Location"] = Location.find_all("span")[1].text
            #dfに個々の遺伝子のデータを順に追加していく。
            if "df" in globals():
                gene_df = pd.DataFrame(gene,index = [0])
                df = pd.concat([gene_df,df],axis=0)
            else:
                df= pd.DataFrame(gene,index = [0])
                
        #どこかしらでエラーが起きた場合はここへ。そのエラー内容をeで取得。
        except Exception as e:
            gene = {}
            gene["name"] = line
            #gene["error"] = e こちらだとエラー内容を出力可能だが、嵩む。
            gene["error"] = "error"
            gene_df = pd.DataFrame(gene,index = [0])
            df = pd.concat([gene_df,df],axis=0)
            
df.to_csv("gene.csv",index = False)
browser.quit()

# %%
gene_df
df
#joined
# Out:
#                                                 name  \
# 0  Irs1 insulin receptor substrate 1 [ Rattus nor...
# 0  Gck glucokinase [ Rattus norvegicus (Norway ra...
# 0  Gckr glucokinase regulator [ Rattus norvegicus...
# 0  Mtnr1b melatonin receptor 1B [ Rattus norvegic...
# 0  G6pc2 glucose-6-phosphatase catalytic subunit ...
# 0  Notch2 notch receptor 2 [ Rattus norvegicus (N...
# 0  Adamts9 ADAM metallopeptidase with thrombospon...
# 0                                            THADA\n
# 0  Tspan8 tetraspanin 8 [ Rattus norvegicus (Norw...
# 0  Cdc123 cell division cycle 123 [ Rattus norveg...
# 0  Jazf1 JAZF zinc finger 1 [ Rattus norvegicus (...
# 0  Wfs1 wolframin ER transmembrane glycoprotein [...
# 0                                             TCF2\n
# 0                                           CDKAL1\n
# 0  Igf2bp2 insulin-like growth factor 2 mRNA bind...
# 0                                           CDKN2A\n
# 0  Hhex hematopoietically expressed homeobox [ Ra...
# 0  Slc30a8 solute carrier family 30 member 8 [ Ra...
# 0  Fto FTO, alpha-ketoglutarate dependent dioxyge...
# 0  Tcf7l2 transcription factor 7 like 2 [ Rattus ...
# 0  Kcnj11 potassium inwardly-rectifying channel, ...
# 0  Pparg peroxisome proliferator-activated recept...
#
#                                          url       gene_type  \
# 0   https://www.ncbi.nlm.nih.gov/gene/25467/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/24385/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/25658/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/192646/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/681817/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/29492/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/312566/  protein coding
# 0                                        NaN             NaN
# 0  https://www.ncbi.nlm.nih.gov/gene/171048/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/116656/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/685879/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/83725/  protein coding
# 0                                        NaN             NaN
# 0                                        NaN             NaN
# 0  https://www.ncbi.nlm.nih.gov/gene/303824/  protein coding
# 0                                        NaN             NaN
# 0   https://www.ncbi.nlm.nih.gov/gene/79237/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/299903/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/291905/  protein coding
# 0  https://www.ncbi.nlm.nih.gov/gene/679869/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/83535/  protein coding
# 0   https://www.ncbi.nlm.nih.gov/gene/25664/  protein coding
#
#                                        also_known_as  \
# 0                                            IRS1IRM
# 0                                  GLK; GLUKA; RNGK2
# 0                                               GLRE
# 0                                       Mt2; Mel1b-r
# 0                                      Igrp; G6pc-rs
# 0  Predicted to enable NF-kappaB binding activity...
# 0  Predicted to enable metalloendopeptidase activ...
# 0                                                NaN
# 0                                      CO-29; Tm4sf3
# 0                                               D123
# 0  Predicted to enable transcription corepressor ...
# 0  Enables several functions, including calmoduli...
# 0                                                NaN
# 0                                                NaN
# 0                                         RGD1305614
# 0                                                NaN
# 0                                                Hex
# 0                                              ZnT-8
# 0                                         RGD1305121
# 0  Predicted to enable several functions, includi...
# 0                                             Kir6.2
# 0                                         PPARgamma2
#
#                                              summary Location  \
# 0  Enables several functions, including SH2 domai...     9q34
# 0  Enables several functions, including adenyl ri...    14q21
# 0  Enables several functions, including carbohydr...     6q14
# 0  Predicted to enable G protein-coupled receptor...     8q12
# 0  Predicted to enable glucose-6-phosphatase acti...     3q21
# 0  Biased expression in Spleen (RPKM 260.8), Lung...     2q34
# 0          Annotation category: suggests misassembly     4q34
# 0                                                NaN      NaN
# 0  Enables integrin binding activity. Involved in...     7q22
# 0  Predicted to be involved in cell division. Pre...  17q12.3
# 0  Biased expression in Brain (RPKM 42.4), Thymus...     4q24
# 0  Biased expression in Brain (RPKM 87.3), Adrena...    14q21
# 0                                                NaN      NaN
# 0                                                NaN      NaN
# 0  The protein encoded by this gene is a member o...    11q23
# 0                                                NaN      NaN
# 0  Enables sequence-specific DNA binding activity...     1q53
# 0  Predicted to enable protein homodimerization a...     7q31
# 0  Predicted to enable 2-oxoglutarate-dependent d...    19p11
# 0  Biased expression in Spleen (RPKM 33.3), Kidne...     1q55
# 0  Enables several functions, including ankyrin b...     1q22
# 0  Enables several functions, including DNA-bindi...     4q42
#
#                                                error
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  Message: no such element: Unable to locate ele...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  Message: no such element: Unable to locate ele...
# 0  Message: no such element: Unable to locate ele...
# 0                                                NaN
# 0  Message: no such element: Unable to locate ele...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN

# %% [markdown]
# <h1>Seleniumの強み</h1>

# %%
#url = "https://www.ncbi.nlm.nih.gov/gene/5468/ortholog/?scope=7776"

#res = requests.get(url)
#soup = BeautifulSoup(res.text,"html.parser")
#soup

#javascriptのせいで、オルソログのページのHTMLはBeautiful　Soupでは上手く取得できない。
#Seleniumから以下のよう(page_source)にする。すると人間が見たままのページのHTMLが出る。
#ここにSeleniumの強みがある。
#browser= webdriver.Chrome()
#browser.get(url)
#source_code = browser.page_source#これを参照しながらfind_elementをすれば良い。
#tag = browser.find_element_by_css_selector('a[data-ga-label="Rattus norvegicus"]')
#tag.click()
#categoryItems = soup.find("dl",attrs={"id":"summaryDl"})
